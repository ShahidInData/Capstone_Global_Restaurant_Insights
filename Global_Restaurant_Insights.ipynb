# %%
import pandas as pd

# %%
df=pd.read_csv('Global_Restaurant_Insights.csv')

# %%
df
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 0             51040                   Truffles             1  Bangalore
# 1             51705                       Toit             1  Bangalore
# 2            308322           Hauz Khas Social             1  New Delhi
# 3             20404                  Peter Cat             1    Kolkata
# 4             56618   AB's  Absolute Barbecues             1  Bangalore
# ...             ...                        ...           ...        ...
# 9543       18486858              6 Packs Momos             1      Noida
# 9544       18431152                  Cafe' Wow             1      Noida
# 9545       18439721  Chef's Basket Pop Up Cafe             1      Noida
# 9546       18428504            The HangoutDeli             1      Noida
# 9547       18254559                   Platters             1      Noida
#
#                                                 Address  \
# ...

# %%
df.head()
# Out:
#    Restaurant ID           Restaurant Name  Country Code       City  \
# 0          51040                  Truffles             1  Bangalore
# 1          51705                      Toit             1  Bangalore
# 2         308322          Hauz Khas Social             1  New Delhi
# 3          20404                 Peter Cat             1    Kolkata
# 4          56618  AB's  Absolute Barbecues             1  Bangalore
#
#                                              Address               Locality  \
# 0  28, 4th 'B' Cross, Koramangala 5th Block, Bang...  Koramangala 5th Block
# 1  298, Namma Metro Pillar 62, 100 Feet Road, Ind...            Indiranagar
# 2              9A & 12, Hauz Khas Village, New Delhi      Hauz Khas Village
# 3        18A, Park Street, Park Street Area, Kolkata       Park Street Area
# 4  90/4, 3rd Floor, Outer Ring Road, Munnekollaly...           Marathahalli
#
#                    Locality Verbose  Longitude  Latitude  \
# ...

# %%
df.tail()
# Out:
#       Restaurant ID            Restaurant Name  Country Code   City  \
# 9543       18486858              6 Packs Momos             1  Noida
# 9544       18431152                  Cafe' Wow             1  Noida
# 9545       18439721  Chef's Basket Pop Up Cafe             1  Noida
# 9546       18428504            The HangoutDeli             1  Noida
# 9547       18254559                   Platters             1  Noida
#
#                                                 Address  \
# 9543                 Spice World Mall, Sector 25, Noida
# 9544  Food Court, 3rd Floor, The Great India Palace ...
# 9545  Inside Big Bazaar, The Great India Place, Sect...
# 9546  320A, 3rd Floor, The Great India Place Mall, S...
# 9547  Shop 1, Tulip Mall, Near HDFC Bank, Sector 48,...
#
#                               Locality  \
# 9543       Spice World Mall, Sector 25
# 9544  The Great India Place, Sector 38
# 9545  The Great India Place, Sector 38
# 9546  The Great India Place, Sector 38
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  Price range  \
# count   9.548000e+03   9548.000000  9548.000000  9548.000000  9548.000000
# mean    9.051850e+06     18.371072    73.261495    26.990862     1.804776
# std     8.791601e+06     56.758626    21.549139     7.819591     0.905629
# min     5.300000e+01      1.000000     0.000000     0.000000     1.000000
# 25%     3.019350e+05      1.000000    77.100000    28.480000     1.000000
# 50%     6.004248e+06      1.000000    77.210000    28.570000     2.000000
# 75%     1.835229e+07      1.000000    77.300000    28.640000     2.000000
# max     1.850065e+07    216.000000   174.830000    55.980000     4.000000
#
#              Votes
# count  9548.000000
# mean    156.778488
# std     426.905371
# min       0.000000
# 25%       5.000000
# 50%      31.000000
# 75%     131.000000
# max    9667.000000

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9543          False            False         False  False    False     False
# 9544          False            False         False  False    False     False
# 9545          False            False         False  False    False     False
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9548 entries, 0 to 9547
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9548 non-null   int64
#  1   Restaurant Name       9548 non-null   object
#  2   Country Code          9548 non-null   int64
#  3   City                  9548 non-null   object
#  4   Address               9548 non-null   object
#  5   Locality              9548 non-null   object
#  6   Locality Verbose      9548 non-null   object
#  7   Longitude             9548 non-null   float64
#  8   Latitude              9548 non-null   float64
#  9   Cuisines              9548 non-null   object
#  10  Average Cost for two  9548 non-null   object
#  11  Currency              9548 non-null   object
#  12  Has Table booking     9548 non-null   bool
#  13  Has Online delivery   9548 non-null   bool
#  14  Is delivering now     9548 non-null   bool
# ...

# %%
top_cuisines = df['Cuisines'].value_counts().head(3)
print(top_cuisines)
# Out:
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: Cuisines, dtype: int64

# %% [markdown]
# North Indian cuisine is the most popular, followed by North Indian-Chinese and Chinese.

# %%
Cuisines_counts = df['Cuisines'].value_counts()
Cuisines_percentages = (Cuisines_counts / len(df)) * 100
top_Cuisines = Cuisines_percentages.head(3)
print(top_Cuisines)
# Out:
# North Indian             9.803100
# North Indian, Chinese    5.351906
# Chinese                  3.707583
# Name: Cuisines, dtype: float64

# %% [markdown]
# North Indian cuisine alone accounts for approximately 9.8% of all restaurants, indicating a strong preference for it among customers.

# %%
top_City = df['City'].value_counts().idxmax()
print("City with the highest number of restaurants:", top_City)
# Out:
# City with the highest number of restaurants: New Delhi

# %% [markdown]
# New Delhi has the highest number of restaurants, indicating its prominence in the restaurant industry.

# %%
df["Aggregate rating"] = pd.to_numeric(df["Aggregate rating"], errors="coerce")
average_ratings = df.groupby('City')['Aggregate rating'].mean()
print(average_ratings)
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# estanbul           4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %%
df["Aggregate rating"] = pd.to_numeric(df["Aggregate rating"], errors="coerce")
average_ratings = df.groupby("City")["Aggregate rating"].mean()
top_city = average_ratings.idxmax()
print("City with the highest average rating:", top_city)
# Out:
# City with the highest average rating: Inner City

# %% [markdown]
# However, Inner City holds the highest average restaurant rating, suggesting a strong customer preference for quality dining experiences there.

# %%
import matplotlib.pyplot as plt

# %%
price_range_counts = df["Price range"].value_counts().sort_index()
plt.figure(figsize=(10, 5))
plt.bar(price_range_counts.index, price_range_counts.values, color="skyblue")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.title("Distribution of Price Ranges Among Restaurants")
plt.xticks(price_range_counts.index)
plt.grid(axis="y", linestyle="--", alpha=0.9)
plt.show()

# %% [markdown]
# Most restaurants are in the lowest price range, indicating a preference for budget-friendly dining, while high-end options are fewer.

# %%
price_range_percentages = (df["Price range"].value_counts(normalize=True) * 100).sort_index()
print(price_range_percentages)
# Out:
# 1.0    46.533305
# 2.0    32.593213
# 3.0    14.736070
# 4.0     6.137411
# Name: Price range, dtype: float64

# %% [markdown]
# Nearly 47% of restaurants fall in the lowest price range, while only about 6% belong to the highest, highlighting a dominance of affordable dining options.

# %%
online_delivery_count = df["Has Online delivery"].value_counts(normalize=True) * 100
print(online_delivery_count)
# Out:
# False    74.329703
# True     25.670297
# Name: Has Online delivery, dtype: float64

# %%
df["Aggregate rating"] = pd.to_numeric(df["Aggregate rating"], errors="coerce")
average_ratings = df.groupby("Has Online delivery")["Aggregate rating"].mean()
print(average_ratings)
# Out:
# Has Online delivery
# False    3.467453
# True     3.381274
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# Only 25.67% of restaurants offer online delivery, and they tend to have slightly lower average ratings compared to those without online delivery.

# %%
df["Aggregate rating"] = pd.to_numeric(df["Aggregate rating"], errors="coerce")

plt.figure(figsize=(8, 5))
plt.hist(df["Aggregate rating"].dropna(), bins=10, color="Green", edgecolor="black")
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")
plt.title("Distribution of Aggregate Ratings")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# The most common restaurant rating is 3.2, with most ratings clustering between 2.5 and 4.0, indicating an average customer satisfaction level.

# %%
df["Votes"] = pd.to_numeric(df["Votes"], errors="coerce")

average_votes = df["Votes"].mean()

average_votes = round(df["Votes"].mean(), 2)

print("Average number of votes received by restaurants:", average_votes)
# Out:
# Average number of votes received by restaurants: 156.78

# %%
cuisine_combinations = df["Cuisines"].value_counts()

print("Most common cuisine combinations:")
print(cuisine_combinations.head(5))
# Out:
# Most common cuisine combinations:
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                353
# North Indian, Mughlai    333
# Name: Cuisines, dtype: int64

# %% [markdown]
# North Indian cuisine is the most common, followed by North Indian-Chinese and Chinese, indicating a strong preference for these flavors.

# %%
df["Aggregate rating"] = pd.to_numeric(df["Aggregate rating"], errors="coerce")

cuisine_ratings = df.groupby("Cuisines")["Aggregate rating"].mean()

top_cuisine_combinations = cuisine_ratings.sort_values(ascending=False)

print("Cuisine combinations with highest ratings:")
print(top_cuisine_combinations.head(5))
# Out:
# Cuisine combinations with highest ratings:
# Cuisines
# Burger, Bar Food, Steak         4.9
# American, BBQ, Sandwich         4.9
# Sunda, Indonesian               4.9
# European, Asian, Indian         4.9
# Italian, Bakery, Continental    4.9
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# Cuisine combinations like Burger-Bar Food-Steak, American-BBQ-Sandwich, and Italian-Bakery-Continental have the highest average ratings of 4.9, indicating strong customer satisfaction.

# %%
df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")

plt.figure(figsize=(10, 6))
plt.scatter(df["Longitude"], df["Latitude"], alpha=0.5, c="brown", edgecolors="black")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Restaurant Locations on Map")
plt.grid(True)
plt.show()

# %% [markdown]
# The restaurant locations are widely dispersed, with noticeable clusters in certain regions, indicating high-density dining areas.

# %%
from sklearn.cluster import KMeans

# %%
df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
df["Latitude"] = pd.to_numeric(df["Latitude"], errors="coerce")

df = df.dropna(subset=["Longitude", "Latitude"])

kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df["Cluster"] = kmeans.fit_predict(df[["Longitude", "Latitude"]])

plt.figure(figsize=(10, 6))
plt.scatter(df["Longitude"], df["Latitude"], c=df["Cluster"], cmap="viridis", alpha=0.6, edgecolors="black")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Clusters of Restaurants")
plt.grid(True)
plt.show()

# %% [markdown]
# The restaurant locations form distinct clusters, indicating specific high-density dining areas with varying regional concentrations.

# %%
restaurant_counts = df["Restaurant Name"].value_counts()

restaurant_chains = restaurant_counts[restaurant_counts > 1]

print("Restaurant chains found in the dataset:")
print(restaurant_chains)
# Out:
# Restaurant chains found in the dataset:
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
#                     ..
# Chaap Point          2
# Punjabi Chicken      2
# Shawarma King's      2
# Italiano             2
# Wood Box Cafe        2
# Name: Restaurant Name, Length: 736, dtype: int64

# %% [markdown]
# The dataset contains multiple restaurant chains, with Cafe Coffee Day, Domino’s Pizza, and Subway having the highest number of outlets.

# %%
df["Aggregate rating"] = pd.to_numeric(df["Aggregate rating"], errors="coerce")
df["Votes"] = pd.to_numeric(df["Votes"], errors="coerce")

restaurant_counts = df["Restaurant Name"].value_counts()
restaurant_chains = restaurant_counts[restaurant_counts > 1].index

chain_data = df[df["Restaurant Name"].isin(restaurant_chains)]

chain_analysis = chain_data.groupby("Restaurant Name").agg(
    Average_Rating=("Aggregate rating", "mean"),
    Total_Votes=("Votes", "sum")
).sort_values(by="Average_Rating", ascending=False)

print("Ratings and Popularity of Restaurant Chains:")
print(chain_analysis.head(10))
# Out:
# Ratings and Popularity of Restaurant Chains:
#                           Average_Rating  Total_Votes
# Restaurant Name
# Talaga Sampireun                   4.900         5514
# Silantro FilMex                    4.850         1364
# AB's Absolute Barbecues            4.850         3151
# AB's  Absolute Barbecues           4.825        13400
# Naturals Ice Cream                 4.800         3094
# Gymkhana                           4.700          328
# The Cheesecake Factory             4.650         3010
# Garota de Ipanema                  4.600           59
# Dishoom                            4.600         1269
# Chili's                            4.580         8156

# %% [markdown]
# Talaga Sampireun, Silantro FilMex, and AB’s Absolute Barbecues have the highest average ratings among restaurant chains, indicating strong customer satisfaction.
